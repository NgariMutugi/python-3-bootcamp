# %%
2+1
# Out:
# 3

# %%
48-8
# Out:
# 40

# %%
50/10
# Out:
# 5.0

# %%
1.5*4500
# Out:
# 6750.0

# %%
7/4
# Out:
# 1.75

# %% [markdown]
# floor division

# %%
7//4
# Out:
# 1

# %% [raw]
# we gonna now try the reminder stuff which is modulo

# %%
7//4
# Out:
# 1

# %%
#powers
3*3
# Out:
# 9

# %%
#roots
9**0.5
# Out:
# 3.0

# %%
6**0.5
# Out:
# 2.449489742783178
